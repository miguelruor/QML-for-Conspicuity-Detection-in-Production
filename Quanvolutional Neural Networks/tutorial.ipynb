# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
n_epochs = 30   # Number of optimization epochs
n_layers = 1    # Number of random layers
n_train = 50    # Size of the train dataset
n_test = 30     # Size of the test dataset

SAVE_PATH = "quanvolution/"  # Data saving folder
PREPROCESS = True           # If False, skip quantum processing and load data from SAVE_PATH
np.random.seed(0)           # Seed for NumPy random number generator
tf.random.set_seed(0)       # Seed for TensorFlow random number generator

# %%
mnist_dataset = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist_dataset.load_data()

# Reduce dataset size
train_images = train_images[:n_train]
train_labels = train_labels[:n_train]
test_images = test_images[:n_test]
test_labels = test_labels[:n_test]

# Normalize pixel values within 0 and 1
train_images = train_images / 255
test_images = test_images / 255

# Add extra dimension for convolution channels
train_images = np.array(train_images[..., tf.newaxis], requires_grad=False)
test_images = np.array(test_images[..., tf.newaxis], requires_grad=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
dev = qml.device("default.qubit", wires=4)
# Random circuit parameters
rand_params = np.random.uniform(high=2 * np.pi, size=(n_layers, 4))

@qml.qnode(dev)
def circuit(phi):
    # Encoding of 4 classical input values
    for j in range(4):
        qml.RY(np.pi * phi[j], wires=j)

    # Random quantum circuit
    RandomLayers(rand_params, wires=list(range(4)))

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(4)]

def quanv(image):
    """Convolves the input image with many applications of the same quantum circuit."""
    out = np.zeros((14, 14, 4))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0, 28, 2):
        for k in range(0, 28, 2):
            # Process a squared 2x2 region of the image with a quantum circuit
            q_results = circuit(
                [
                    image[j, k, 0],
                    image[j, k + 1, 0],
                    image[j + 1, k, 0],
                    image[j + 1, k + 1, 0]
                ]
            )
            # Assign expectation values to different channels of the output pixel (j/2, k/2)
            for c in range(4):
                out[j // 2, k // 2, c] = q_results[c]
    return out

# %%
if PREPROCESS == True:
    q_train_images = []
    print("Quantum pre-processing of train images:")
    for idx, img in enumerate(train_images):
        print("{}/{}        ".format(idx + 1, n_train), end="\r")
        q_train_images.append(quanv(img))
    q_train_images = np.asarray(q_train_images)

    q_test_images = []
    print("\nQuantum pre-processing of test images:")
    for idx, img in enumerate(test_images):
        print("{}/{}        ".format(idx + 1, n_test), end="\r")
        q_test_images.append(quanv(img))
    q_test_images = np.asarray(q_test_images)

    # Save pre-processed images
    np.save(SAVE_PATH + "q_train_images.npy", q_train_images)
    np.save(SAVE_PATH + "q_test_images.npy", q_test_images)


# Load pre-processed images
q_train_images = np.load(SAVE_PATH + "q_train_images.npy")
q_test_images = np.load(SAVE_PATH + "q_test_images.npy")
# Out:
# Quantum pre-processing of train images:
# 50/50
# Quantum pre-processing of test images:
# 30/30

# %%
n_samples = 4
n_channels = 4
fig, axes = plt.subplots(1 + n_channels, n_samples, figsize=(10, 10))
for k in range(n_samples):
    axes[0, 0].set_ylabel("Input")
    if k != 0:
        axes[0, k].yaxis.set_visible(False)
    axes[0, k].imshow(train_images[k, :, :, 0], cmap="gray")

    # Plot all output channels
    for c in range(n_channels):
        axes[c + 1, 0].set_ylabel("Output [ch. {}]".format(c))
        if k != 0:
            axes[c, k].yaxis.set_visible(False)
        axes[c + 1, k].imshow(q_train_images[k, :, :, c], cmap="gray")

plt.tight_layout()
plt.show()

# %%
def MyModel():
    """Initializes and returns a custom Keras model
    which is ready to be trained."""
    model = keras.models.Sequential([
        keras.layers.Flatten(),
        keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

# %%
q_model = MyModel()

q_history = q_model.fit(
    q_train_images,
    train_labels,
    validation_data=(q_test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 13/13 - 0s - 27ms/step - accuracy: 0.1000 - loss: 2.9175 - val_accuracy: 0.1667 - val_loss: 2.2576
# Epoch 2/30
# 13/13 - 0s - 2ms/step - accuracy: 0.3200 - loss: 2.0199 - val_accuracy: 0.2667 - val_loss: 2.1425
# Epoch 3/30
# 13/13 - 0s - 2ms/step - accuracy: 0.5000 - loss: 1.6209 - val_accuracy: 0.4000 - val_loss: 1.8758
# Epoch 4/30
# 13/13 - 0s - 2ms/step - accuracy: 0.7800 - loss: 1.3102 - val_accuracy: 0.4667 - val_loss: 1.7360
# Epoch 5/30
# 13/13 - 0s - 2ms/step - accuracy: 0.8800 - loss: 1.0777 - val_accuracy: 0.4667 - val_loss: 1.6391
# Epoch 6/30
# 13/13 - 0s - 2ms/step - accuracy: 0.9400 - loss: 0.8776 - val_accuracy: 0.5333 - val_loss: 1.5521
# Epoch 7/30
# 13/13 - 0s - 2ms/step - accuracy: 0.9600 - loss: 0.7302 - val_accuracy: 0.5667 - val_loss: 1.4797
# Epoch 8/30
# 13/13 - 0s - 2ms/step - accuracy: 0.9800 - loss: 0.6137 - val_accuracy: 0.6000 - val_loss: 1.4213
# Epoch 9/30
# 13/13 - 0s - 2ms/step - accuracy: 0.9800 - loss: 0.5209 - val_accuracy: 0.6333 - val_loss: 1.3742
# Epoch 10/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.4476 - val_accuracy: 0.6333 - val_loss: 1.3347
# Epoch 11/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.3883 - val_accuracy: 0.6000 - val_loss: 1.3011
# Epoch 12/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.3400 - val_accuracy: 0.6000 - val_loss: 1.2728
# Epoch 13/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.3001 - val_accuracy: 0.6000 - val_loss: 1.2486
# Epoch 14/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2669 - val_accuracy: 0.6000 - val_loss: 1.2276
# Epoch 15/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2389 - val_accuracy: 0.6000 - val_loss: 1.2093
# Epoch 16/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2153 - val_accuracy: 0.6000 - val_loss: 1.1932
# Epoch 17/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1950 - val_accuracy: 0.6000 - val_loss: 1.1790
# Epoch 18/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1776 - val_accuracy: 0.6000 - val_loss: 1.1662
# Epoch 19/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1625 - val_accuracy: 0.6000 - val_loss: 1.1548
# Epoch 20/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1494 - val_accuracy: 0.6000 - val_loss: 1.1445
# Epoch 21/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1379 - val_accuracy: 0.6333 - val_loss: 1.1352
# Epoch 22/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1277 - val_accuracy: 0.6333 - val_loss: 1.1266
# Epoch 23/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1187 - val_accuracy: 0.6333 - val_loss: 1.1189
# Epoch 24/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1106 - val_accuracy: 0.6333 - val_loss: 1.1117
# Epoch 25/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1034 - val_accuracy: 0.6333 - val_loss: 1.1051
# Epoch 26/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0970 - val_accuracy: 0.6333 - val_loss: 1.0990
# Epoch 27/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0911 - val_accuracy: 0.6333 - val_loss: 1.0934
# Epoch 28/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0859 - val_accuracy: 0.6333 - val_loss: 1.0882
# Epoch 29/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0811 - val_accuracy: 0.6333 - val_loss: 1.0833
# Epoch 30/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.0767 - val_accuracy: 0.6333 - val_loss: 1.0788

# %%
c_model = MyModel()

c_history = c_model.fit(
    train_images,
    train_labels,
    validation_data=(test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 13/13 - 0s - 18ms/step - accuracy: 0.0600 - loss: 2.4157 - val_accuracy: 0.2333 - val_loss: 2.2259
# Epoch 2/30
# 13/13 - 0s - 2ms/step - accuracy: 0.4000 - loss: 2.0245 - val_accuracy: 0.3333 - val_loss: 2.0693
# Epoch 3/30
# 13/13 - 0s - 2ms/step - accuracy: 0.5600 - loss: 1.7360 - val_accuracy: 0.4000 - val_loss: 1.9265
# Epoch 4/30
# 13/13 - 0s - 2ms/step - accuracy: 0.7600 - loss: 1.4884 - val_accuracy: 0.4333 - val_loss: 1.8000
# Epoch 5/30
# 13/13 - 0s - 2ms/step - accuracy: 0.8600 - loss: 1.2776 - val_accuracy: 0.5333 - val_loss: 1.6927
# Epoch 6/30
# 13/13 - 0s - 2ms/step - accuracy: 0.8800 - loss: 1.1010 - val_accuracy: 0.5333 - val_loss: 1.6040
# Epoch 7/30
# 13/13 - 0s - 2ms/step - accuracy: 0.8800 - loss: 0.9546 - val_accuracy: 0.5333 - val_loss: 1.5314
# Epoch 8/30
# 13/13 - 0s - 2ms/step - accuracy: 0.9000 - loss: 0.8335 - val_accuracy: 0.5667 - val_loss: 1.4717
# Epoch 9/30
# 13/13 - 0s - 2ms/step - accuracy: 0.9400 - loss: 0.7329 - val_accuracy: 0.5667 - val_loss: 1.4221
# Epoch 10/30
# 13/13 - 0s - 2ms/step - accuracy: 0.9800 - loss: 0.6488 - val_accuracy: 0.5667 - val_loss: 1.3804
# Epoch 11/30
# 13/13 - 0s - 2ms/step - accuracy: 0.9800 - loss: 0.5779 - val_accuracy: 0.5667 - val_loss: 1.3450
# Epoch 12/30
# 13/13 - 0s - 2ms/step - accuracy: 0.9800 - loss: 0.5178 - val_accuracy: 0.5667 - val_loss: 1.3147
# Epoch 13/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.4663 - val_accuracy: 0.5667 - val_loss: 1.2885
# Epoch 14/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.4221 - val_accuracy: 0.6000 - val_loss: 1.2657
# Epoch 15/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.3837 - val_accuracy: 0.6667 - val_loss: 1.2457
# Epoch 16/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.3503 - val_accuracy: 0.7333 - val_loss: 1.2282
# Epoch 17/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.3210 - val_accuracy: 0.7333 - val_loss: 1.2126
# Epoch 18/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2952 - val_accuracy: 0.7333 - val_loss: 1.1988
# Epoch 19/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2724 - val_accuracy: 0.7333 - val_loss: 1.1865
# Epoch 20/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2521 - val_accuracy: 0.7333 - val_loss: 1.1755
# Epoch 21/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2340 - val_accuracy: 0.7333 - val_loss: 1.1655
# Epoch 22/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2178 - val_accuracy: 0.7333 - val_loss: 1.1566
# Epoch 23/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.2033 - val_accuracy: 0.7333 - val_loss: 1.1485
# Epoch 24/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1901 - val_accuracy: 0.7333 - val_loss: 1.1412
# Epoch 25/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1783 - val_accuracy: 0.7333 - val_loss: 1.1346
# Epoch 26/30
# 13/13 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.1675 - val_accuracy: 0.7333 - val_loss: 1.1285
# Epoch 27/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1577 - val_accuracy: 0.7333 - val_loss: 1.1230
# Epoch 28/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1488 - val_accuracy: 0.7333 - val_loss: 1.1179
# Epoch 29/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1406 - val_accuracy: 0.7333 - val_loss: 1.1133
# Epoch 30/30
# 13/13 - 0s - 2ms/step - accuracy: 1.0000 - loss: 0.1331 - val_accuracy: 0.7333 - val_loss: 1.1090

# %%
plt.style.use("ggplot")
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 9))

ax1.plot(q_history.history["val_accuracy"], "-ob", label="With quantum layer")
ax1.plot(c_history.history["val_accuracy"], "-og", label="Without quantum layer")
ax1.set_ylabel("Accuracy")
ax1.set_ylim([0, 1])
ax1.set_xlabel("Epoch")
ax1.legend()

ax2.plot(q_history.history["val_loss"], "-ob", label="With quantum layer")
ax2.plot(c_history.history["val_loss"], "-og", label="Without quantum layer")
ax2.set_ylabel("Loss")
ax2.set_ylim(top=2.5)
ax2.set_xlabel("Epoch")
ax2.legend()
plt.tight_layout()
plt.show()
